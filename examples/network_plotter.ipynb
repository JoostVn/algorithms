# %%
from matplotlib import pyplot as plt
from algorithms.neural.nn import Layer, NeuralNetwork
from algorithms.neural.plotting import NetworkPlotter

# %%
nn = NeuralNetwork(input_dim=6)
nn.add_layer(Layer(size=8, input_dim=6))
nn.add_layer(Layer(size=8, input_dim=8))
nn.add_layer(Layer(size=4, input_dim=8))

nn.random_init()
plotter = NetworkPlotter(nn)
fig, ax = plt.subplots(figsize=(6,4))
plotter.pyplot_structure(ax, node_size=400, font_size=6, font_offset=(0,0))
